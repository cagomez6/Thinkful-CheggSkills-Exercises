# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/lahman_pitching.csv')

df = df[df['yearID'] >= 1950]

# %%
df.hist('BAOpp')
# Out:
# array([[<Axes: title={'center': 'BAOpp'}>]], dtype=object)

# %%
df.hist('HR')
# Out:
# array([[<Axes: title={'center': 'HR'}>]], dtype=object)

# %%
df.hist('W')
df.hist('L')
# Out:
# array([[<Axes: title={'center': 'L'}>]], dtype=object)

# %%
import pandas as pd
from matplotlib import pyplot as plt
import statistics

df = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/lahman_pitching.csv')

# Filter it
df = df[df['yearID'] >= 1950]
df.head()

means = []
for i in range(1000):
  # Your code goes here...
    samples = df.sample(100)
    means.append(samples['G'].mean())
    
plt.xlim([min(means)-5, max(means)+5])

plt.hist(means, alpha=0.5)
plt.title('Distribution of Games')
plt.xlabel('Average Games')
plt.ylabel('Count')

plt.show()
